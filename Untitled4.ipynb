# %% [markdown]
# <a href="https://colab.research.google.com/github/ROSHAN-KUMAR-NAYAK/Finance-Market-Risk-And-Volatility-Dashboard-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Required Library

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install yfinance

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %% [markdown]
# Select Portfolio Stocks

# %%
stocks= ['AAPL','MSFT','TSLA','JNJ','XOM']

# %% [markdown]
# Download Historical Data

# %%
data=yf.download(stocks,start="2020-01-01",end="2024-01-01")
data
# Out:
# /tmp/ipykernel_891/4165657448.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download(stocks,start="2020-01-01",end="2024-01-01")
# [*********************100%***********************]  5 of 5 completed
# Price            Close                                                 \
# Ticker            AAPL         JNJ        MSFT        TSLA        XOM
# Date
# 2020-01-02   72.400543  122.638206  152.158386   28.684000  53.306404
# 2020-01-03   71.696632  121.218353  150.263779   29.534000  52.877850
# 2020-01-06   72.267921  121.067131  150.652161   30.102667  53.283852
# 2020-01-07   71.928047  121.806442  149.278549   31.270666  52.847782
# 2020-01-08   73.085114  121.789673  151.656311   32.809334  52.050819
# ...                ...         ...         ...         ...        ...
# 2023-12-22  191.609467  145.440445  368.236572  252.539993  94.430153
# 2023-12-26  191.065140  146.076630  368.315308  256.609985  94.643265
# ...

# %%
print(data.columns)
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',  'JNJ'),
#             ( 'Close', 'MSFT'),
#             ( 'Close', 'TSLA'),
#             ( 'Close',  'XOM'),
#             (  'High', 'AAPL'),
#             (  'High',  'JNJ'),
#             (  'High', 'MSFT'),
#             (  'High', 'TSLA'),
#             (  'High',  'XOM'),
#             (   'Low', 'AAPL'),
#             (   'Low',  'JNJ'),
#             (   'Low', 'MSFT'),
#             (   'Low', 'TSLA'),
#             (   'Low',  'XOM'),
#             (  'Open', 'AAPL'),
#             (  'Open',  'JNJ'),
#             (  'Open', 'MSFT'),
#             (  'Open', 'TSLA'),
#             (  'Open',  'XOM'),
#             ('Volume', 'AAPL'),
#             ('Volume',  'JNJ'),
#             ('Volume', 'MSFT'),
#             ('Volume', 'TSLA'),
#             ('Volume',  'XOM')],
#            names=['Price', 'Ticker'])

# %% [markdown]
# Extract Adjusted Closing Price

# %%
Price_data =data ['Close']
Price_data
# Out:
# Ticker            AAPL         JNJ        MSFT        TSLA        XOM
# Date
# 2020-01-02   72.400543  122.638206  152.158386   28.684000  53.306404
# 2020-01-03   71.696632  121.218353  150.263779   29.534000  52.877850
# 2020-01-06   72.267921  121.067131  150.652161   30.102667  53.283852
# 2020-01-07   71.928047  121.806442  149.278549   31.270666  52.847782
# 2020-01-08   73.085114  121.789673  151.656311   32.809334  52.050819
# ...                ...         ...         ...         ...        ...
# 2023-12-22  191.609467  145.440445  368.236572  252.539993  94.430153
# 2023-12-26  191.065140  146.076630  368.315308  256.609985  94.643265
# 2023-12-27  191.164078  146.273071  367.735291  261.440002  94.198502
# 2023-12-28  191.589676  146.488251  368.924805  253.179993  92.836388
# 2023-12-29  190.550461  146.637955  369.671936  248.479996  92.641800
#
# [1006 rows x 5 columns]

# %% [markdown]
# Check Missing Values

# %%
Price_data.isnull().sum()
# Out:
# Ticker
# AAPL    0
# JNJ     0
# MSFT    0
# TSLA    0
# XOM     0
# dtype: int64

# %% [markdown]
# Handle Missing Data (Forward Fill)

# %%
Price_data=Price_data.fillna(method='ffill')
# Out:
# /tmp/ipykernel_891/1874422882.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Price_data=Price_data.fillna(method='ffill')

# %% [markdown]
# Check again Missing Values

# %%
price_data.isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# complete code

# %%
import pandas as pd
import yfinance as yf

stocks = ['AAPL','MSFT','TSLA','JNJ','XOM']

data = yf.download(stocks,start="2020-01-01",end="2024-01-01")

price_data = data['Close']

price_data.plot(figsize=(12,6),title="Stock Price Trend")
# Out:
# /tmp/ipykernel_891/1230711532.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stocks,start="2020-01-01",end="2024-01-01")
# [*********************100%***********************]  5 of 5 completed
# <Axes: title={'center': 'Stock Price Trend'}, xlabel='Date'>

# %% [markdown]
# Download the data set and show the data set

# %%
import pandas as pd
import yfinance as yf

stocks = ['AAPL','MSFT','TSLA','JNJ','XOM']

data = yf.download(stocks,start="2020-01-01",end="2024-01-01")

data
# Out:
# /tmp/ipykernel_891/2736271388.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stocks,start="2020-01-01",end="2024-01-01")
# [*********************100%***********************]  5 of 5 completed
# Price            Close                                                 \
# Ticker            AAPL         JNJ        MSFT        TSLA        XOM
# Date
# 2020-01-02   72.400543  122.638206  152.158386   28.684000  53.306404
# 2020-01-03   71.696632  121.218353  150.263779   29.534000  52.877850
# 2020-01-06   72.267921  121.067131  150.652161   30.102667  53.283852
# 2020-01-07   71.928047  121.806442  149.278549   31.270666  52.847782
# 2020-01-08   73.085114  121.789673  151.656311   32.809334  52.050819
# ...                ...         ...         ...         ...        ...
# 2023-12-22  191.609467  145.440445  368.236572  252.539993  94.430153
# 2023-12-26  191.065140  146.076630  368.315308  256.609985  94.643265
# ...

# %% [markdown]
# Output Data set

# %%
print(price_data)
# Out:
# Ticker            AAPL         JNJ        MSFT        TSLA        XOM
# Date
# 2020-01-02   72.400543  122.638206  152.158386   28.684000  53.306404
# 2020-01-03   71.696632  121.218353  150.263779   29.534000  52.877850
# 2020-01-06   72.267921  121.067131  150.652161   30.102667  53.283852
# 2020-01-07   71.928047  121.806442  149.278549   31.270666  52.847782
# 2020-01-08   73.085114  121.789673  151.656311   32.809334  52.050819
# ...                ...         ...         ...         ...        ...
# 2023-12-22  191.609467  145.440445  368.236572  252.539993  94.430153
# 2023-12-26  191.065140  146.076630  368.315308  256.609985  94.643265
# 2023-12-27  191.164078  146.273071  367.735291  261.440002  94.198502
# 2023-12-28  191.589676  146.488251  368.924805  253.179993  92.836388
# 2023-12-29  190.550461  146.637955  369.671936  248.479996  92.641800
#
# [1006 rows x 5 columns]

# %% [markdown]
# Save Clean Data

# %%
price_data.to_csv ("stock_data.csv")

# %% [markdown]
# Download File

# %%
from google.colab import files
files.download("stock_data.csv")

# %% [markdown]
# Preview Data Visualization

# %%
price_data.plot(figsize=(12,6),title="Stock Price Trend")
# Out:
# <Axes: title={'center': 'Stock Price Trend'}, xlabel='Date'>

# %% [markdown]
# Review /Validation Check
# Collect Historical Data

# %%
import yfinance as yf

data = yf.download("AAPL", start="2022-01-01", end="2024-01-01")
print(type(data))
print (data)
# Out:
# /tmp/ipykernel_891/263141036.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2022-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.103668  178.955006  173.895967  174.013387  104487900
# 2022-01-04  175.843262  179.013730  175.275708  178.710386   99310400
# 2022-01-05  171.165848  176.303172  170.891858  175.755193   94537600
# 2022-01-06  168.308517  171.537695  167.956243  168.993491   96904000
# 2022-01-07  168.474823  170.402543  167.359291  169.179371   86709100
# ...                ...         ...         ...         ...        ...
# 2023-12-22  191.609467  193.400854  190.985939  193.173208   37149600
# ...

# %% [markdown]
# Check The Type Of Data

# %%
data=yf.download("AAPL")
# Out:
# /tmp/ipykernel_891/3738391584.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download("AAPL")
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Check Missing Values (Data Integrity Check)

# %%
data.isnull().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %% [markdown]
# Example Forward Fll Method:

# %%
data= data.fillna(method="ffill")
# Out:
# /tmp/ipykernel_891/3339933094.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data= data.fillna(method="ffill")

# %% [markdown]
# Check Duplicate Data

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Remove Duplicates

# %%
data =data.drop_duplicates()

# %% [markdown]
# Adjust For Stock Spilt  & Dividends

# %%
returns=data['Close'].pct_change()

# %% [markdown]
# Validate Date Order

# %%
data=data.sort_index

# %% [markdown]
# First Check The Type Of Data

# %%
type(data)
# Out:
# method

# %% [markdown]
# Check Outliers(Abnormal Prices)

# %%
import numpy as np

z_scores = np.abs((data['Close'] - data['Close'].mean()) / data['Close'].std())
outliers = data[z_scores > 3]
print(outliers)
# Out:
# Price      Close High  Low Open Volume
# Ticker      AAPL AAPL AAPL AAPL   AAPL
# Date
# 2022-01-03   NaN  NaN  NaN  NaN    NaN
# 2022-01-04   NaN  NaN  NaN  NaN    NaN
# 2022-01-05   NaN  NaN  NaN  NaN    NaN
# 2022-01-06   NaN  NaN  NaN  NaN    NaN
# 2022-01-07   NaN  NaN  NaN  NaN    NaN
# ...          ...  ...  ...  ...    ...
# 2023-12-22   NaN  NaN  NaN  NaN    NaN
# 2023-12-26   NaN  NaN  NaN  NaN    NaN
# 2023-12-27   NaN  NaN  NaN  NaN    NaN
# 2023-12-28   NaN  NaN  NaN  NaN    NaN
# 2023-12-29   NaN  NaN  NaN  NaN    NaN
#
# [501 rows x 5 columns]

# %% [markdown]
# Validate Data Consistency

# %%
invalid = data[(data['High'] < data['Open']) | (data['Low'] > data['Close'])]
print(invalid)
# Out:
# Price      Close High  Low Open Volume
# Ticker      AAPL AAPL AAPL AAPL   AAPL
# Date
# 2022-01-03   NaN  NaN  NaN  NaN    NaN
# 2022-01-04   NaN  NaN  NaN  NaN    NaN
# 2022-01-05   NaN  NaN  NaN  NaN    NaN
# 2022-01-06   NaN  NaN  NaN  NaN    NaN
# 2022-01-07   NaN  NaN  NaN  NaN    NaN
# ...          ...  ...  ...  ...    ...
# 2023-12-22   NaN  NaN  NaN  NaN    NaN
# 2023-12-26   NaN  NaN  NaN  NaN    NaN
# 2023-12-27   NaN  NaN  NaN  NaN    NaN
# 2023-12-28   NaN  NaN  NaN  NaN    NaN
# 2023-12-29   NaN  NaN  NaN  NaN    NaN
#
# [501 rows x 5 columns]

# %% [markdown]
# Final Clean Dataset

# %%
clean_data = data.dropna()
